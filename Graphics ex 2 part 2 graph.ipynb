# %%
data=loadtxt("sunspots.txt",float)
data[:,0]
data[:,1]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-422080b4dc93> in <module>()
# ----> 1 data=loadtxt("sunspots.txt",float)
#       2 data[:,0]
#       3 data[:,1]
#
# /usr/lib/pymodules/python2.7/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack)
#     633             fh = bz2.BZ2File(fname)
#     634         else:
# --> 635             fh = open(fname, 'U')
#     636     elif hasattr(fname, 'readline'):
#     637         fh = fname
#
# IOError: [Errno 2] No such file or directory: 'sunspots.txt'

# %%
x = arange(-pi,pi+0.01, .001)
b = cosh(x)
U = -(1/b)**2
i = complex(0,1.)
P = (0**2 + tanh(x))**2/(0**2+1)
Q = (0.5**2 + tanh(x)**2/(0.5**2+1))
R = (1**2 + tanh(x)**2/(1**2+1))
S = (2**2 + tanh(x)**2/(2**2+1))
plot(x,U, color="blue")
plot(x, P,color="red")
plot(x, Q,color="red")
plot(x, R-0.5,color="red")
plot(x, S-3.1,color="red")
xticks(arange(-pi,pi+0.01,pi/2),('$-\pi$',r'$-\frac{\pi}{2}$','0',r'$+\frac{\pi}{2}$','$+\pi$'))
xlabel("x(rad)")
ylabel("U(x),$\Psi^2$(x)")
grid(True)
