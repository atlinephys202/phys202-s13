# %%
sum_=0
for i in range(1,1000):
    if i%3==0 or i%5==0:
        sum_ +=i
print sum_
# Out:
# 233168

# %%
sum_=0
for i in range(10):
    if i%3==0 or i%5==0:
        sum_+=i
print sum_
# Out:
# 23
