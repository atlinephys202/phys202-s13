# %%
from Electrostatics import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')

x,y = meshgrid(arange(-5,5,0.5),arange(-5,5,0.5))
Vdipole = dipolePotential(x,y,1e-9,2.,0);
contour(x,y,Vdipole,cmap=cm.coolwarm)

mask = (y==0)
p = ax.plot_surface(x,y,Vdipole,cstride=1,rstride=1,cmap=cm.coolwarm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-19f036b4741f> in <module>()
#       6 x,y = meshgrid(arange(-5,5,0.5),arange(-5,5,0.5))
#       7 Vdipole = dipolePotential(x,y,1e-9,2.,0);
# ----> 8 contour(x,y,Vdipole,cmap=cm.coolwarm)
#       9
#      10 mask = (y==0)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2498         ax.hold(hold)
#    2499     try:
# -> 2500         ret = ax.contour(*args, **kwargs)
#    2501         draw_if_interactive()
#    2502     finally:
#
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/mplot3d/axes3d.pyc in contour(self, X, Y, Z, *args, **kwargs)
#    1947
#    1948         jX, jY, jZ = art3d.rotate_axes(X, Y, Z, zdir)
# -> 1949         cset = Axes.contour(self, jX, jY, jZ, *args, **kwargs)
#    1950         self.add_contour_set(cset, extend3d, stride, zdir, offset)
# ...

# %%
def Temp(Resistance):
    T={3.239:"10",3.118:"11",3.004:"12",2.897:"13",2.795:"14",2.700:"15",2.610:"16",2.526:"17",2.446:"18",2.371:"19",2.300:"20",2.233:"21",2.169:"22",2.110:"23",2.053:"24",2.000:"25",1.950:"26",1.902:"27",1.857:"28",1.815:"29",1.774:"30",1.736:"31",1.700:"32",1.666:"33",1.634:"34",1.603:"35",1.574:"36",1.547:"37",1.521:"38",1.496:"39"}
    if Resistance<=3.239 and Resistance>=1.496:
        print T[Resistance]
    else:
        print "requested Resistance is not in this chart"
        
Temp(3.118)
# Out:
# 11

# %%
from scipy.interpolate import interp1d

Resistance = arange(3.239,1.496+0.001, 0.001)

tempNew = interp1d(Resistance,Temp(Resistance))

plot(Resistance,tempNew,color= "red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-70a841809d5c> in <module>()
#       3 Resistance = arange(3.239,1.496+0.001, 0.001)
#       4
# ----> 5 tempNew = interp1d(Resistance,Temp(Resistance))
#       6
#       7 plot(Resistance,tempNew,color= "red")
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/interpolate.pyc in __init__(self, x, y, kind, axis, copy, bounds_error, fill_value)
#     215             raise ValueError("the x array must have exactly one dimension.")
#     216         if y.ndim == 0:
# --> 217             raise ValueError("the y array must have at least one dimension.")
#     218
#     219         # Force-cast y to a floating-point type, if it's not yet one
#
# ValueError: the y array must have at least one dimension.
# requested Resistance is not in this chart
