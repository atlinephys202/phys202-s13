# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')

x = arange(-6,6,.235)
y = arange(-6,6,.235)

X,Y = meshgrid(x,y)

G = e**(-(X**2)-(Y**2))

p = ax.plot_surface(X,Y,G,rstride=1,cstride=1,cmap=cm.coolwarm)
cb = fig.colorbar(p,shrink=0.75)

# %%
from Electrostatics import *

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')

x = arange(-4,4,0.78)
y = arange(-4,4,0.78)

X,Y = meshgrid(x,y)

first = pointPotential(0,0,1e-9,0,2)
second = pointPotential(0,0,1e-9,0,-2)
third = pointPotential(0,0,-1e-9,2,0)
forth = pointPotential(0,0,-1e-9,-2,0)

p = ax.plot_surface(X,Y,first,cstride=1,rstride=1,cmap=cm.coolwarm)
p = ax.plot_surface(X,Y,second,cstride=1,rstride=1,cmap=cm.coolwarm)
p = ax.plot_surface(X,Y,third,cstride=1,rstride=1,cmap=cm.coolwarm)
p = ax.plot_surface(X,Y,forth,cstride=1,rstride=1,cmap=cm.coolwarm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-823b873c3bdf> in <module>()
#      13 forth = pointPotential(0,0,-1e-9,-2,0)
#      14
# ---> 15 p = ax.plot_surface(X,Y,first,cstride=1,rstride=1,cmap=cm.coolwarm)
#      16 p = ax.plot_surface(X,Y,second,cstride=1,rstride=1,cmap=cm.coolwarm)
#      17 p = ax.plot_surface(X,Y,third,cstride=1,rstride=1,cmap=cm.coolwarm)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1356         # If they can not be fitted to that shape,
#    1357         # then an exception is automatically thrown.
# -> 1358         X.shape = (rows, cols)
#    1359         Y.shape = (rows, cols)
#    1360
#
# ValueError: total size of new array must be unchanged

# %%
levels = arange(-4,4,-.78)
contour(X,Y,first,levels,linewidths=3,cmap=cm.coolwarm)
contour(X,Y,second,levels,linewidths=3,cmap=cm.coolwarm)
contour(X,Y,third,levels,linewidths=3,cmap=cm.coolwarm)
contour(X,Y,forth,levels,linewidths=3,cmap=cm.coolwarm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-320d7620536e> in <module>()
#       1 levels = arange(-4,4,-.78)
# ----> 2 contour(X,Y,first,levels,linewidths=3,cmap=cm.coolwarm)
#       3 contour(X,Y,second,levels,linewidths=3,cmap=cm.coolwarm)
#       4 contour(X,Y,third,levels,linewidths=3,cmap=cm.coolwarm)
#       5 contour(X,Y,forth,levels,linewidths=3,cmap=cm.coolwarm)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/pyplot.py in contour(*args, **kwargs)
#    2186         ax.hold(hold)
#    2187     try:
# -> 2188         ret = ax.contour(*args, **kwargs)
#    2189         draw_if_interactive()
#    2190     finally:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in contour(self, *args, **kwargs)
#    7314         if not self._hold: self.cla()
#    7315         kwargs['filled'] = False
# -> 7316         return mcontour.QuadContourSet(self, *args, **kwargs)
#    7317     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    7318
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#    1104         are described in QuadContourSet.contour_doc.
#    1105         """
# -> 1106         ContourSet.__init__(self, ax, *args, **kwargs)
#    1107
#    1108     def _process_args(self, *args, **kwargs):
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#     698         if self.origin == 'image': self.origin = mpl.rcParams['image.origin']
#     699
# --> 700         self._process_args(*args, **kwargs)
#     701         self._process_levels()
#     702
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1117             self.zmax = args[0].zmax
#    1118         else:
# -> 1119             x, y, z = self._contour_args(args, kwargs)
#    1120
#    1121             x0 = ma.minimum(x)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1164             args = args[1:]
#    1165         elif Nargs <=4:
# -> 1166             x,y,z = self._check_xyz(args[:3], kwargs)
#    1167             args = args[3:]
#    1168         else:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1196         z = ma.asarray(args[2], dtype=np.float64)
#    1197         if z.ndim != 2:
# -> 1198             raise TypeError("Input z must be a 2D array.")
#    1199         else: Ny, Nx = z.shape
#    1200         if x.shape == z.shape and y.shape == z.shape:
#
# TypeError: Input z must be a 2D array.

# %%
#def pointPotential(X,Y,q,posx,posy):
 #       """takes q in coulomb and points in meters"""
  #      Vxy=(8.89e9)*q/((X-posx)**2.+(Y-posy)**2.)**(1/2.)
   #     return Vxy

#def dipolePotential(X,Y,q,posx,angle):
 #       """takes q in coulombs and points in meters"""
  #      k=8.9e9
   #     Vxy = k*q/((X-posx*cos(angle))**2.+Y**2.)**(1/2.) + k*q/((X+posx*cos(-1*angle))**2.+Y**2)**(1/2.)
    #    return Vxy
