# %%
data=loadtxt("sunspots.txt")
x = data[:,0]
y = data[:,1]
sum_=0
for i in y:
    sum_ += i
    avg = sum_/(x+1)
    plot (x,avg)
    ylim(0,300)

# %%
plot(x,y,color="red",linewidth=.5)
xlabel("year")
ylabel("number of sunspots")

# %%
for i in x:
    if i<=999:
        return i
# Out:
#   File "<ipython-input-1-08dd7643dafe>", line 3
# SyntaxError: 'return' outside function

# %%
data2=loadtxt("stars.txt")
x2=data2[:,0]
y2=data2[:,1]
pylab.scatter(x2,y2,color="red",linewidth=.5,label="STARS")
xlim(16000,0)
ylim(20,-10)
xlabel("Temperature(K)",fontsize=12)
ylabel("Magnitude",fontsize=12)
grid(True)
legend(loc="lower left")
annotate("B",(12000,-6),color="blue",fontsize=30)
annotate("A",(9500,-6),color="green",fontsize=30)
annotate("F",(7300,-6),color="yellow",fontsize=30)
annotate("G",(6000,-6),color="orange",fontsize=30)
annotate("K",(4300,-6),color="red",fontsize=30)
annotate("M",(3000,-6),color="pink",fontsize=30)
